# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('test_measure.csv')
df = df.drop(columns='ID_test').groupby('ID').mean().reset_index()
df.to_csv('avg_test_measure.csv', index=False)

# %%
df2
# Out:
#       Age  Weight  Height  Humidity  Temperature  Sex   ID ID_test
# 0    10.8    48.8   163.0      39.0         20.7    1  543   543_1
# 1    11.8    41.0   150.0      41.0         22.3    1   11    11_1
# 2    12.2    46.0   160.0      37.0         21.5    0  829   829_1
# 3    13.2    71.0   190.0      49.0         23.8    1  284   284_1
# 4    13.7    53.8   169.7      40.0         25.3    0  341   341_1
# ..    ...     ...     ...       ...          ...  ...  ...     ...
# 987  59.1    64.7   172.0      38.0         24.4    0  856   856_2
# 988  59.7    65.2   172.0      51.0         16.8    0  856   856_3
# 989  61.3   102.0   185.0      56.0         20.5    0  390   390_1
# 990  61.6    74.0   169.0      46.0         23.9    0  596   596_1
# 991  63.0    83.5   171.5      48.0         22.2    0  296   296_1
#
# [992 rows x 8 columns]

# %%
df2.map

# %%
df2 = pd.read_csv('subject-info.csv')
df2 = df2.drop(columns='ID_test').groupby('ID').mean().reset_index().dropna()
merged = df2.merge(df, on='ID', how='inner')
merged['Sex'] = merged['Sex'].map({1: 'Male', 0: 'Female'})

merged.to_csv('averages.csv', index=False)

# %%
merged['Sex'] = merged['Sex'].map({1: 'Male', 0: 'Female'})
merged
# Out:
#       ID        Age  Weight      Height   Humidity  Temperature     Sex  \
# 0      3  16.600000    63.8  176.000000  43.000000    24.600000  Female
# 1      9  24.500000    72.0  167.000000  69.000000    22.000000    Male
# 2     10  29.300000    81.0  178.000000  65.000000    21.500000  Female
# 3     11  11.800000    41.0  150.000000  41.000000    22.300000    Male
# 4     12  27.100000   108.0  176.000000  41.000000    24.300000    Male
# ..   ...        ...     ...         ...        ...          ...     ...
# 825  853  16.900000    75.0  178.000000  48.000000    20.800000  Female
# 826  854  34.600000    75.5  185.500000  46.000000    20.300000  Female
# 827  855  42.650000    60.7  165.600000  42.450000    22.050000  Female
# 828  856  59.166667    65.3  171.766667  42.333333    18.733333  Female
# 829  857  29.000000    80.1  188.000000  53.000000    26.300000  Female
#
#            time      Speed          HR          VO2         VCO2         RR  \
# ...

# %%
merged['Humidity'].describe()
# Out:
# count    830.000000
# mean      48.289880
# std        8.206506
# min       28.000000
# 25%       42.462500
# 50%       47.000000
# 75%       54.000000
# max       69.000000
# Name: Humidity, dtype: float64
